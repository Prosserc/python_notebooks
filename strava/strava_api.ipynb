# %%
## to get access code...
## past into browser: https://www.strava.com/oauth/authorize?client_id=62286&response_type=code&redirect_uri=http://localhost/exchange_token&approval_prompt=force&scope=profile:read_all,activity:read_all
## and click authorise, will not find page, but note code in url redirect

# %%
import requests, json, os, pandas as pd, datetime as dt, time

# %%
access_code = 'b6293da66f50f2324c3ae74c6ec36a7203b69831'
client_id = 62286
secret = os.environ['STRAVA_API_SECRET']

# %%
def get_tokens(client_id: str, access_code: str, secret: str):
    response = requests.post(
                    url = 'https://www.strava.com/oauth/token',
                    data = {
                            'client_id': client_id,
                            'client_secret': f'{secret}',
                            'code': f'{access_code}',
                            'grant_type': 'authorization_code'
                            }
                )
    strava_tokens = response.json()
    return strava_tokens

# %%
# get token from stored file if poss to skip having to generate new access code as desc above
if os.path.exists('strava_tokens.json'):
    with open('strava_tokens.json', 'r') as f:
        token_data = json.load(f)
        
    # refresh if expired
    if token_data['expires_at'] < time.time():
        print('Token expired, calling Strava auth API with refresh token')
        resp = requests.post(url = 'https://www.strava.com/oauth/token',
                             data = {
                                     'client_id': client_id,
                                     'client_secret': secret,
                                     'grant_type': 'refresh_token',
                                     'refresh_token': token_data['refresh_token']
                                    }
                        )
        token_data = resp.json()    
        with open('strava_tokens.json', 'w') as f:
            json.dump(token_data, f) # update the file
else:
    token_data = get_tokens(client_id, access_code, secret)
    with open('strava_tokens.json', 'w') as f:
        json.dump(token_data, f)
        
# confirm we got data...
access_token=token_data['access_token']
print(token_data)
# Out:
# Token expired, calling Strava auth API with refresh token
# {'token_type': 'Bearer', 'access_token': '20f5bc4dfd0170ab8d6d643b72b2279386867bed', 'expires_at': 1615301830, 'expires_in': 21600, 'refresh_token': '071225a0d5c3f016839984092f80b11d22f5fbcb'}

# %%
def get_activities(access_token:str, n:int=50):
    url = f'https://www.strava.com/api/v3/athlete/activities?per_page={n}&access_token={access_token}'
    resp = requests.get(url)
    return resp.json()

# %%
data = get_activities(access_token)  # from strava / settings / My API App

# %%
orig_df = pd.json_normalize(data)
orig_df
# Out:
#     resource_state                     name  distance  moving_time  \
# 0                2              Morning Run    8684.8         3156
# 1                2             Evening Walk    1981.3         1240
# 2                2  Hilly Ride with Andy ⛰️   47471.0        10069
# 3                2              Morning Run   15024.8         5643
# 4                2              Morning Run    6534.9         2349
# 5                2  Speed endurance session   14012.1         5171
# 6                2              Morning Run    8680.8         3305
# 7                2            Long Slow Run   19788.9         8019
# 8                2            Afternoon Run    8576.2         3251
# 9                2           Afternoon walk    5007.3         3376
# 10               2         5 x 1k intervals   10013.9         3348
# 11               2            Afternoon Run    6489.8         2501
# 12               2           Afternoon walk    2801.4         1470
# 13               2           Ride with Andy   35209.3         6192
# 14               2              Morning Run   15240.5         5980
# 15               2          Progression Run   10484.1         3723
# 16               2            Afternoon Run    9011.3         3415
# 17               2            Afternoon Run    5180.2         1924
# 18               2         Walk with Rachel    2697.5         2466
# 19               2           Afternoon Walk    3331.1         2686
# 20               2              Morning Run    9471.1         3574
# 21               2                Tempo Run    8698.8         3087
# 22               2                 Easy Run    6768.8         2685
# 23               2              Indoor Ride   20102.6         3468
# 24               2             Evening Walk    5393.7         3012
# 25               2         Quick KB workout       0.0          735
# 26               2           Afternoon Ride   27352.8         5643
# 27               2            Afternoon Run   10555.5         4109
# 28               2            Afternoon Run    8636.6         3298
# 29               2              Indoor Ride   16525.5         2770
# 30               2            Afternoon Run   10455.4         4157
# 31               2              Indoor Ride   20073.7         2785
# 32               2                  Hard 5k    5009.5         1604
# 33               2              Indoor Ride   30003.3         4983
# 34               2            Afternoon Run   11601.2         4602
# 35               2            Threshold Run    6939.7         2387
# 36               2           Afternoon walk    3699.9         2687
# 37               2      Snowy Afternoon Run   11775.5         5174
# 38               2           Afternoon Walk    6599.9         4250
# 39               2            Run, walk run    9964.5         4384
# 40               2            Afternoon Run    7846.2         3128
# 41               2              Morning Run    6445.1         2492
# 42               2                Lunch Run    9673.1         3799
# 43               2              Indoor Ride   45016.3         7785
# 44               2                Lunch Run    4546.9         1694
# 45               2              Indoor Ride   22428.4         3603
# 46               2            Walk with RCD    2633.6         2507
# 47               2            Afternoon Run   14450.4         6319
# 48               2           Afternoon Ride   33571.3         6347
# 49               2            Afternoon Run   10013.0         4117
#
#     elapsed_time  total_elevation_gain     type  workout_type          id  \
# 0           3159                  90.4      Run           0.0  4916196135
# 1           1240                  24.9     Walk           NaN  4913913231
# 2          12471                 895.4     Ride          10.0  4906781004
# 3           5731                 187.2      Run           2.0  4898346347
# 4           2352                  84.8      Run           0.0  4892854322
# 5           5193                 212.8      Run           3.0  4884966433
# 6           3310                  83.1      Run           0.0  4875395191
# 7           8024                 262.2      Run           2.0  4864689964
# 8           3262                  87.1      Run           0.0  4854294293
# 9           3609                  92.4     Walk           NaN  4848466785
# 10          3351                  61.5      Run           3.0  4842584642
# 11          2516                  84.3      Run           0.0  4836675408
# 12          1487                  35.0     Walk           NaN  4831260661
# 13          6815                 463.3     Ride          10.0  4825157065
# 14          6029                 127.8      Run           2.0  4816099223
# 15          3743                 120.6      Run           3.0  4807886699
# 16          3441                  87.2      Run           0.0  4802314939
# 17          1924                  37.0      Run           0.0  4797302267
# 18          2597                  57.0     Walk           NaN  4785149385
# 19          2756                  69.6     Walk           NaN  4781898316
# 20          3586                  93.0      Run           0.0  4774124626
# 21          3087                  89.1      Run           3.0  4763789326
# 22          2694                  84.6      Run           0.0  4761195521
# 23          3468                   0.0     Ride          10.0  4758623728
# 24          3012                  61.1     Walk           NaN  4756452869
# 25           735                   0.0  Workout           NaN  4754168319
# 26          7095                 449.8     Ride          10.0  4750724616
# 27          4114                 130.9      Run           0.0  4745802504
# 28          3314                  89.0      Run           0.0  4738787549
# 29          2770                   0.0     Ride          10.0  4734730456
# 30          4157                 126.1      Run           0.0  4728841022
# 31          2785                   0.0     Ride          10.0  4724306382
# 32          1619                  31.5      Run           0.0  4717313822
# 33          4983                   0.0     Ride          10.0  4711041189
# 34          4606                 120.1      Run           2.0  4706437778
# 35          2387                  83.0      Run           0.0  4696530529
# 36          3162                  44.5     Walk           NaN  4690268000
# 37          5219                 145.4      Run           0.0  4679385831
# 38          4279                  66.8     Walk           NaN  4674827695
# 39          4441                 102.1      Run           0.0  4669126229
# 40          3141                  79.8      Run           NaN  4657889473
# 41          2495                  82.1      Run           0.0  4650590117
# 42          3816                  92.8      Run           NaN  4640993336
# 43          7785                   0.0     Ride          10.0  4637122594
# 44          2011                  53.4      Run           0.0  4629303570
# 45          3603                   0.0     Ride          10.0  4625721732
# 46          2801                  42.5     Walk           NaN  4616229506
# 47          6624                 186.8      Run           0.0  4609740262
# 48          7699                 391.6     Ride          10.0  4599129224
# 49          4159                  61.8      Run           0.0  4593127309
#
#                                           external_id  ...  has_kudoed  \
# 0                              garmin_push_6399197362  ...       False
# 1   d8de78de-4bbd-450f-87ba-8862c6a721c7-activity.fit  ...       False
# 2                              garmin_push_6389824698  ...       False
# 3                              garmin_push_6381811575  ...       False
# 4                              garmin_push_6376331785  ...       False
# 5                              garmin_push_6368512731  ...       False
# 6                              garmin_push_6359146093  ...       False
# 7                              garmin_push_6348658579  ...       False
# 8                              garmin_push_6338479836  ...       False
# 9                              garmin_push_6332771649  ...       False
# 10                             garmin_push_6326996374  ...       False
# 11                             garmin_push_6321175102  ...       False
# 12                             garmin_push_6315720771  ...       False
# 13                             garmin_push_6309545840  ...       False
# 14                             garmin_push_6300841827  ...       False
# 15                             garmin_push_6292544059  ...       False
# 16                             garmin_push_6286981036  ...       False
# 17                             garmin_push_6282098705  ...       False
# 18                             garmin_push_6270084241  ...       False
# 19                             garmin_push_6266800554  ...       False
# 20                             garmin_push_6259014289  ...       False
# 21                             garmin_push_6248712737  ...       False
# 22                             garmin_push_6246151863  ...       False
# 23                             garmin_push_6243534801  ...       False
# 24                             garmin_push_6241353524  ...       False
# 25                             garmin_push_6238966515  ...       False
# 26                             garmin_push_6235499440  ...       False
# 27                             garmin_push_6230713121  ...       False
# 28                             garmin_push_6223855368  ...       False
# 29                             garmin_push_6219893853  ...       False
# 30                             garmin_push_6214147521  ...       False
# 31                             garmin_push_6209700589  ...       False
# 32                             garmin_push_6202796929  ...       False
# 33                             garmin_push_6196647434  ...       False
# 34                             garmin_push_6192170256  ...       False
# 35                             garmin_push_6182418679  ...       False
# 36                             garmin_push_6176268078  ...       False
# 37                             garmin_push_6165369671  ...       False
# 38                             garmin_push_6160687728  ...       False
# 39                             garmin_push_6155172549  ...       False
# 40                             garmin_push_6144296632  ...       False
# 41                             garmin_push_6136949432  ...       False
# 42                             garmin_push_6127418435  ...       False
# 43                             garmin_push_6123545311  ...       False
# 44                             garmin_push_6116098669  ...       False
# 45                             garmin_push_6112476784  ...       False
# 46                             garmin_push_6102994268  ...       False
# 47                             garmin_push_6096532922  ...       False
# 48                             garmin_push_6085844600  ...       False
# 49                             garmin_push_6080010591  ...       False
#
#    suffer_score athlete.id athlete.resource_state       map.id  \
# 0          63.0   33557595                      1  a4916196135
# 39  g{e_IrsaLcA`@qAt@CRJbBAX?vHNtAWt@QrDBbAD~@Vp@x...                  2
# 40  e{e_I|saLHIRARE`CeAVAd@H`@ZZn@`@RVCTp@VrAb@~An...                  2
# 41  q{e_IltaL?I]HkAh@a@NKHZpB?r@Cv@@zDB|@Nz@h@hBPt...                  2
# 42  g{e_IzsaLIE_@HiB`AQZPx@PfB?|BIbCD|@?x@Ov@Kv@Kh...                  2
# 43                                               None                  2
# 44  a{e_IftaLECK@gCjA@|@Fx@GtB@z@C|BVnB[x@OhBEdAHz...                  2
# 45                                               None                  2
# 46  ade_I`m`LPKL]b@g@NDT?b@L\HdBJf@RNIl@LpA~@t@\Xn...                  2
# 47  m{e_I`taLO?iC`AGHNxBJ~HBn@H`@OPS|AGtAGh@@n@Az@...                  2
# 48  g_f_ItuaLg@XXfGBfDLnAz@lDv@zBpDtHYt@iAb@{ClBoG...                  2
# 49  e{e_IlsaLAiA[aCYwAQgBIEIOc@LgAd@w@NOwAO_EcB{DY...                  2
#
#    average_watts kilojoules device_watts
# 0            NaN        NaN          NaN
# 1            NaN        NaN          NaN
# 2           98.7      994.0        False
# 3            NaN        NaN          NaN
# 4            NaN        NaN          NaN
# 5            NaN        NaN          NaN
# 6            NaN        NaN          NaN
# 7            NaN        NaN          NaN
# 8            NaN        NaN          NaN
# 9            NaN        NaN          NaN
# 10           NaN        NaN          NaN
# 11           NaN        NaN          NaN
# 12           NaN        NaN          NaN
# 13         107.9      667.9        False
# 14           NaN        NaN          NaN
# 15           NaN        NaN          NaN
# 16           NaN        NaN          NaN
# 17           NaN        NaN          NaN
# 18           NaN        NaN          NaN
# 19           NaN        NaN          NaN
# 20           NaN        NaN          NaN
# 21           NaN        NaN          NaN
# 22           NaN        NaN          NaN
# 23           NaN        NaN        False
# 24           NaN        NaN          NaN
# 25           NaN        NaN          NaN
# 26          95.8      540.4        False
# 27           NaN        NaN          NaN
# 28           NaN        NaN          NaN
# 29           NaN        NaN        False
# 30           NaN        NaN          NaN
# 31           NaN        NaN        False
# 32           NaN        NaN          NaN
# 33           NaN        NaN        False
# 34           NaN        NaN          NaN
# 35           NaN        NaN          NaN
# 36           NaN        NaN          NaN
# 37           NaN        NaN          NaN
# 38           NaN        NaN          NaN
# 39           NaN        NaN          NaN
# 40           NaN        NaN          NaN
# 41           NaN        NaN          NaN
# 42           NaN        NaN          NaN
# 43           NaN        NaN        False
# 44           NaN        NaN          NaN
# 45           NaN        NaN        False
# 46           NaN        NaN          NaN
# 47           NaN        NaN          NaN
# 48          87.3      554.1        False
# 49           NaN        NaN          NaN
#
# [50 rows x 58 columns]

# %%
runs = orig_df[orig_df['type'] == 'Run']  # filter by activity
df = pd.DataFrame()
df['Date'] = runs['start_date'].apply(lambda v: v[:10])
df['Distance (km)'] = runs['distance'].apply(lambda v: v / 1000)
df['Elev (m)'] = runs['total_elevation_gain']
df['Pace (Excel)'] = runs.apply(lambda row: (row['elapsed_time'] / 60 / 60 /24) / (row['distance'] / 1000), axis=1)  # val actually in days, but works when formatted as a duration in Excel
df['HR (bpm)'] = runs['average_heartrate']

df['gap_exp'] = runs.apply(lambda row: 1 + (row['total_elevation_gain'] / row['distance']), axis=1)  # calc the exponent to use in grade adjusted pace calc
df['Speed (km/h)'] = runs.apply(lambda row: (row['distance'] / 1000) / (row['elapsed_time'] / 60 / 60), axis=1)
df['My GAS (km/h)'] = df.apply(lambda row: row['Speed (km/h)'] ** row['gap_exp'], axis=1)
df.drop(columns=['gap_exp'], inplace=True)  # only used as a calc step

def format_duration(seconds):
    minutes, seconds = divmod(int(seconds), 60)
    hours, minutes = divmod(minutes, 60)
    #print(f'hrs: {hours}, mins: {minutes}, secs: {seconds}')
    return '{:2d}:{:02d}:{:02d}'.format(hours, minutes, seconds)
    
def format_pace(row):
    secs_per_km = row['elapsed_time']/(row['distance'] / 1000)
    return format_duration(secs_per_km)  # will format into h:mm:ss
    
def format_my_GAP(row):
    gap_hrs_per_km = 1 / row['My GAS (km/h)'] 
    gap_secs_per_km = int(gap_hrs_per_km * 60 * 60)
    return format_duration(gap_secs_per_km)  # will format into h:mm:ss

df['Time'] = runs['elapsed_time'].apply(format_duration)
df['Pace (min/km)'] = runs.apply(format_pace, axis=1)
df['My GAP (min/km)'] = df.apply(format_my_GAP, axis=1)
#df

# %%
# try adding shoe to this (we need to hit another API)
cache = {}

def get_gear(access_token, gear_id:int):
    url = f'https://www.strava.com/api/v3/gear/{gear_id}?access_token={access_token}'
    if not gear_id in cache:
        resp = requests.get(url)
        cache[gear_id] = resp.json()
    return cache[gear_id]

def row_to_gear_name(gear_id):
    gear = get_gear(access_token, gear_id)
    try:
        return gear['name'] if 'name' in gear else gear['brand_name'] + ' ' + gear['model_name']
    except KeyError:
        return f'Failed to get name from resp: {gear}'

try:
    df['Shoe'] = runs['gear_id'].apply(row_to_gear_name)
except Exception as e:
    print(f"Tried and failed to lookup shoes from gear ids, got error: {repr(e)}")

df
# Out:
#           Date  Distance (km)  Elev (m)  Pace (Excel)  HR (bpm)  Speed (km/h)  \
# 0   2021-03-09         8.6848      90.4      0.004210     162.6      9.897208
# 3   2021-03-06        15.0248     187.2      0.004415     159.9      9.438018
# 4   2021-03-05         6.5349      84.8      0.004166     165.3     10.002398
# 5   2021-03-03        14.0121     212.8      0.004289     169.2      9.713761
# 6   2021-03-02         8.6808      83.1      0.004413     159.3      9.441353
# 7   2021-02-28        19.7889     262.2      0.004693     158.8      8.878370
# 8   2021-02-26         8.5762      87.1      0.004402     163.0      9.464844
# 10  2021-02-24        10.0139      61.5      0.003873     171.8     10.757995
# 11  2021-02-23         6.4898      84.3      0.004487     165.0      9.285882
# 14  2021-02-20        15.2405     127.8      0.004579     158.5      9.100315
# 15  2021-02-18        10.4841     120.6      0.004132     173.6     10.083559
# 16  2021-02-17         9.0113      87.2      0.004420     161.8      9.427690
# 17  2021-02-16         5.1802      37.0      0.004299     172.1      9.692682
# 20  2021-02-12         9.4711      93.0      0.004382     166.5      9.508076
# 7                HOKA ONE ONE Rincon2
# 8   ASICS Gel-Cumulus 22 (Winterized)
# 10               HOKA ONE ONE Rincon2
# 11                      Saucony Iso 2
# 14                      Saucony Iso 2
# 15               HOKA ONE ONE Rincon2
# 16                      Saucony Iso 2
# 17  ASICS Gel-Cumulus 22 (Winterized)
# 20  ASICS Gel-Cumulus 22 (Winterized)
# 21               HOKA ONE ONE Rincon2
# 22  ASICS Gel-Cumulus 22 (Winterized)
# 27                      Saucony Iso 2
# 28  ASICS Gel-Cumulus 22 (Winterized)
# 30  ASICS Gel-Cumulus 22 (Winterized)
# 32               HOKA ONE ONE Rincon2
# 34                      Saucony Iso 2
# 35               HOKA ONE ONE Rincon2
# 37  ASICS Gel-Cumulus 22 (Winterized)
# 39  ASICS Gel-Cumulus 22 (Winterized)
# 40  ASICS Gel-Cumulus 22 (Winterized)
# 41                      Saucony Iso 2
# 42  ASICS Gel-Cumulus 22 (Winterized)
# 44               HOKA ONE ONE Rincon2
# 47  ASICS Gel-Cumulus 22 (Winterized)
# 49                      Saucony Iso 2

# %%
downloads_dir = os.path.join(os.getenv('userprofile'), 'Downloads')
runs.to_excel(os.path.join(downloads_dir, f"raw_recent_runs_{dt.date.today().strftime('%Y_%m_%d')}.xlsx"))
df.to_excel(os.path.join(downloads_dir, f"recent_runs_{dt.date.today().strftime('%Y_%m_%d')}.xlsx"))

# %%
#https://www.strava.com/api/v3/activities/4875395191/streams?keys=time,distance,altitude,velocity_smooth,heartrate,cadence,grade_smooth&key_by_type=false

keys = 'time,distance,altitude,velocity_smooth,heartrate,cadence,grade_smooth'

# get the raw measurement data for an activity (as an Excel sheet)
def get_activity_stream(id):    
    url = f'https://www.strava.com/api/v3/activities/{id}/streams?keys={keys}&key_by_type=true&access_token={access_token}'
    resp = requests.get(url)
    return resp.json()

latest_id = runs['id'][0]
stream_data = get_activity_stream(latest_id)

headers = keys.split(',')
cols = []
for key in headers:
    cols.append(stream_data[key]['data'])
    
rows = map(list, zip(*cols))  # transpose the columns to get rows of data

stream_df = pd.DataFrame(rows, columns=headers)
stream_df
# Out:
#      time  distance  altitude  velocity_smooth  heartrate  cadence  \
# 0       0       0.7      95.3              0.0        120        0
# 1       4       6.3      95.3              1.4        124       85
# 2       6      11.8      95.2              1.9        127       85
# 3       8      17.5      95.2              2.1        131       85
# 4      10      23.9      95.2              2.9        135       85
# ..    ...       ...       ...              ...        ...      ...
# 328  2323    6456.4      94.3              2.6        171       86
# 329  2331    6477.5      94.7              2.6        171       86
# 330  2339    6498.4      95.0              2.6        172       85
# 331  2347    6521.1      95.2              2.7        170       87
# 332  2352    6535.6      95.3              2.9        170       88
#
#      grade_smooth
# 0            -0.9
# 1            -0.6
# 2            -0.4
# 3            -0.7
# 4            -0.3
# ..            ...
# 328           2.7
# 329           1.8
# 330           1.3
# 331           1.0
# 332           0.8
#
# [333 rows x 7 columns]

# %%
stream_df.to_excel(os.path.join(downloads_dir, f'activity_stream_{latest_id}.xlsx'))
