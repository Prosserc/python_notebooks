# %%
from diskos.reader import build_reader
import diskos.spec as spec
from diskos.sender_specific.merge import AptAnalId, ANAL_ID_COL, IGI_ID

# %%
block_no = '11'
reader = build_reader(r'c:\data\diskos\6406_12-3_S__ROCK_AND_CORE__GCH_RAW_1.ASC', quiet_mode=True)
spec.SUPPRESS_WARNINGS = True  # some rows have missing cells - we know
parsed_file =reader.parse_file()
block = next((b for b in parsed_file.blocks if b.block_def.block_no == block_no))
df_src = block.as_dataframe
df_src
# Out:
#        AnalID PopnNum PopnMean PopnRead PopnLRange PopnURange PopnStdev  \
# 0  133098WVRA       1     0.45       11       0.41       0.51      0.03
# 1  133099WVRA       1     0.56       16       0.47       0.63      0.05
# 2  133105WVRA       1     0.39       39       0.31       0.47      0.05
# 3  133107WVRA       1     0.40       55       0.30       0.49      0.05
# 4  133109WVRA       1     0.38       48       0.29       0.48      0.05
# 5  133113WVRA       1     0.45       55       0.35       0.54      0.05
# 6  133118WVRA       1     0.43       46       0.34       0.53      0.05
# 7  133122WVRA       1     0.51       55       0.41       0.62      0.06
# 8  133126WVRA       1     0.52       48       0.43       0.63      0.06
# 9  133131WVRA       1     0.51       55       0.43       0.59      0.04
#
#   PopnNum_2 PopnMean_2 PopnRead_2  ... PopnRead_2 PopnLRange_2 PopnURange_2  \
# 0         2       0.66          9  ...
# 1                                  ...
# ...

# %%
from diskos.sender_specific.transformations import ExpandHeadersByAnalCode
transformer = ExpandHeadersByAnalCode()

# %%
df1 = transformer.apply(df_src)
df1
# Out:
#        AnalID PopnNum.VR PopnMean.VR PopnRead.VR PopnLRange.VR PopnURange.VR  \
# 0  133098WVRA          1        0.45          11          0.41          0.51
# 1  133099WVRA          1        0.56          16          0.47          0.63
# 2  133105WVRA          1        0.39          39          0.31          0.47
# 3  133107WVRA          1        0.40          55          0.30          0.49
# 4  133109WVRA          1        0.38          48          0.29          0.48
# 5  133113WVRA          1        0.45          55          0.35          0.54
# 6  133118WVRA          1        0.43          46          0.34          0.53
# 7  133122WVRA          1        0.51          55          0.41          0.62
# 8  133126WVRA          1        0.52          48          0.43          0.63
# 9  133131WVRA          1        0.51          55          0.43          0.59
#
#   PopnStdev.VR PopnNum_2.VR PopnMean_2.VR PopnRead_2.VR  ... PopnRead_2.VR  \
# ...

# %%
df2 = transformer.expand_cols_by_anal_code(df_src)
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\chris prosser\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 'PopnNum_2.VR'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(df_src.columns.tolist())
# Out:
# ['AnalID', 'PopnNum', 'PopnMean', 'PopnRead', 'PopnLRange', 'PopnURange', 'PopnStdev', 'PopnNum_2', 'PopnMean_2', 'PopnRead_2', 'PopnLRange_2', 'PopnURange_2', 'PopnStdev_2', 'PopnNum_2', 'PopnMean_2', 'PopnRead_2', 'PopnLRange_2', 'PopnURange_2', 'PopnStdev_2', 'PopnNum_2', 'PopnMean_2', 'PopnRead_2', 'PopnLRange_2', 'PopnURange_2', 'PopnStdev_2']
