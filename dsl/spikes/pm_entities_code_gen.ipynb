# %%
import os
pm_path = os.path.join(os.getenv('appdata'), 'PigiPlus', 'PropertyModel.json')

# %%
# load pm config json into big dictionary

import json
with open(pm_path, 'r', encoding='utf-8') as f:
    pm_entities = json.load(f)

# %%
# check it worked

for name, entities in pm_entities.items():
    print(f'{len(entities):>5} {name}')
# Out:
#  3128 Properties
#    79 PropertyGroups
#   101 PropertyGroupAliases
#  9147 PropertyGroupProperties
# 56321 PropertyGroupPropertyAliases
# 14650 Equations
#     3 IndicatorGroups
#    12 Indicators
#     2 RatioGroups
#     5 Ratios
#    36 UnitOfMeasureGroups
#   134 UnitsOfMeasure
#   462 UnitOfMeasureAliases
# 34727 MeasurementContexts
#    59 Codelists
#  2317 CodelistEntries
#   371 CodelistEntryAliases

# %%
# todo - can't find mappings from GUID yet
#guid_to_data_type: Dict[str, str] = {   # Hard coding as they don't seem to be in the json
  
#}

# %%
# types listed in order for dependency graph
t_str = "PropertyGroup, PropertyGroupAlias, IndicatorGroup, Indicator, \
    RatioGroup, Ratio, UnitOfMeasureGroup, UnitOfMeasure, UnitOfMeasureAlias, \
    Codelist, CodelistEntry, CodelistEntryAlias, DataType, Property, \
    PropertyGroupProperty, PropertyGroupPropertyAlias, MeasurementContext, Equation"
types = [t.strip() for t in t_str.split(",")]
types
# Out:
# ['PropertyGroup',
#  'PropertyGroupAlias',
#  'IndicatorGroup',
#  'Indicator',
#  'RatioGroup',
#  'Ratio',
#  'UnitOfMeasureGroup',
#  'UnitOfMeasure',
#  'UnitOfMeasureAlias',
#  'Codelist',
#  'CodelistEntry',
#  'CodelistEntryAlias',
#  'DataType',
#  'Property',
#  'PropertyGroupProperty',
#  'PropertyGroupPropertyAlias',
#  'MeasurementContext',
#  'Equation']

# %%
def to_python_name(name: str, sep="_") -> str:
    f = lambda i, l: f"{'_' if i != 0 and l.isupper() else ''}{l.lower()}"
    return "".join(f(i, l) for i, l in enumerate(name))

def get_field_name(name: str, sep="_"):
    # replace _id as we will link entities not ids
    return to_python_name(name, sep).replace("_id", "").replace("_value_descriptor", "")

# test
names = ["PropertyGroupAlias", "UnitOfMeasureId"]
for n in names:
    print(f"{n} -> {get_field_name(n)}")
# Out:
# PropertyGroupAlias -> property_group_alias
# UnitOfMeasureId -> unit_of_measure

# %%
## gen code to create classes
import inflect  # for singlular / plural conv
from typing import Any

p = inflect.engine()

def get_type(entity_key: str, field_key: str) -> str:    
    # handle id types - we will link to entity not guid
    if field_key.endswith("Id"):
        t = field_key.replace("Id", "").replace("Default", "").replace("ValueDescriptor", "")
    else:        
        # can't just look at first, some are none type...
        entities = pm_entities[entity_key]
        dist_types = set(type(e[field_key]).__name__ for e in entities)
        if 'NoneType' in dist_types and len(dist_types) > 1:
            dist_types.remove('NoneType')
        if len(dist_types) > 1:
            print(f"Expected 1 type for {entity_key}.{field_key} (excl None). "
                  f"Got: {dist_types}")
        t = next(iter(dist_types))
    if t.strip() == "":
        return "Any  # Failed to determine type"
    return t
    
def dict_element_to_field(field_key: str, entity_key: str, cls_name: str) -> str:
    if field_key == f"{cls_name}Id":
        return "id: str"
    field_type = get_type(entity_key, field_key)
    return f"{get_field_name(field_key)}: {field_type}"

def get_entity_key(cls_name: str):
    entity_key = p.plural_noun(cls_name)
    # fix plural conv mistakes!
    entity_key = entity_key.replace('Aliass', 'Aliases')
    entity_key = entity_key.replace('UnitOfMeasures', 'UnitsOfMeasure')
    entity_key = entity_key.replace('ys', 'ies')
    return entity_key

# using types defined above as this has the order I want
for cls_name in types:
    try:
        entity_key = get_entity_key(cls_name)
        field_keys = pm_entities[entity_key][0].keys()
        fields = [dict_element_to_field(field_key, entity_key, cls_name)
                  for field_key in field_keys]
            
        fields_str = "\n    ".join(fields)

        cl = f"""
@dataclass(frozen=True)
class {cls_name}:
    {fields_str}
        """
        print(cl)
    except Exception as e:
        print(f"# failed to autogen class for {cls_name}:\n# {repr(e)}\n")
# Out:
# @dataclass(frozen=True)
# class PropertyGroup:
#     id: str
#     short_name: str
#     long_name: str
#     igi_code: str
#     is_analysis: bool
#     list_position: int
#
#
# @dataclass(frozen=True)
# class PropertyGroupAlias:
#     id: str
#     property_group: PropertyGroup
#     alias: str
#
#
# @dataclass(frozen=True)
# class IndicatorGroup:
#     id: str
#     name: str
#
#
# @dataclass(frozen=True)
# class Indicator:
#     id: str
#     indicator_group: IndicatorGroup
#     long_name: str
#     short_name: str
#     igi_code: str
#     is_default: bool
#     is_null_equivalent: bool
#     position_in_indicator_group: int
#
#
# @dataclass(frozen=True)
# class RatioGroup:
#     id: str
#     name: str
#
#
# @dataclass(frozen=True)
# class Ratio:
#     id: str
#     ratio_group: RatioGroup
#     long_name: str
#     symbol: str
#     igi_code: str
#     is_base: bool
#     is_null_equivalent: bool
#     position_in_ratio_group: int
#     conversion_parameters: dict
#
#
# @dataclass(frozen=True)
# class UnitOfMeasureGroup:
#     id: str
#     name: str
#
#
# @dataclass(frozen=True)
# class UnitOfMeasure:
#     id: str
#     unit_of_measure_group: UnitOfMeasureGroup
#     long_name: str
#     symbol: str
#     is_base: bool
#     is_null_equivalent: bool
#     conversion_parameters: dict
#     position_in_unit_of_measure_group: int
#
#
# @dataclass(frozen=True)
# class UnitOfMeasureAlias:
#     id: str
#     unit_of_measure: UnitOfMeasure
#     alias: str
#
#
# @dataclass(frozen=True)
# class Codelist:
#     id: str
#     name: str
#
#
# @dataclass(frozen=True)
# class CodelistEntry:
#     id: str
#     codelist: Codelist
#     short_name: str
#     long_name: str
#
#
# @dataclass(frozen=True)
# class CodelistEntryAlias:
#     id: str
#     codelist_entry: CodelistEntry
#     alias: str
#
# # failed to autogen class for DataType:
# # KeyError('DataTypes')
#
#
# @dataclass(frozen=True)
# class Property:
#     id: str
#     short_name: str
#     long_name: str
#     igi_code: str
#     codelist: Codelist
#     data_type: DataType
#     default_ratio: Ratio
#     physical_characteristics: dict
#
#
# @dataclass(frozen=True)
# class PropertyGroupProperty:
#     id: str
#     property_group: PropertyGroup
#     property: Property
#     position_in_property_group: int
#     ion_channel: str
#     description: str
#
#
# @dataclass(frozen=True)
# class PropertyGroupPropertyAlias:
#     id: str
#     property_group_property: PropertyGroupProperty
#     alias: str
#
#
# @dataclass(frozen=True)
# class MeasurementContext:
#     id: str
#     property_group_property: PropertyGroupProperty
#     indicator: Indicator
#     default_ratio: Ratio
#     default_unit_of_measure: UnitOfMeasure
#     default_value: float
#     decimal_places: int
#     absolute_min: float
#     absolute_max: float
#     typical_min: float
#     typical_max: float
#     typical_error: float
#
#
# @dataclass(frozen=True)
# class Equation:
#     id: str
#     measurement_context: MeasurementContext
#     value_descriptor: Any  # Failed to determine type
#     equation_expression: str

# %%
# gen code to populate objects from json
get_lookup_name = lambda key: f"self.lookup_{get_field_name(key)}".replace("_default", "")
get_method_name = lambda t: f"get_{to_python_name(t)}_lookup"

def get_field_value(key):
    # usually just keying into dictionary, but for objects get from dict
    # order of types respects dependency graph
    field_name = get_field_name(key)
    if key.endswith("Id"):
        return f"lookup({get_lookup_name(key)}, id=c['{key}'])"
    else: 
        return f"c['{key}']"

methods = []
lookup_calls = []

for t in types:
    try:
        entity_key = get_entity_key(t)
        field_keys = pm_entities[entity_key][0].keys()
        assignments = []
        for field_key in field_keys: 
            if field_key == f"{t}Id":
                assignments.append(f"id=c['{field_key}']")
            else:
                assignments.append(f"{get_field_name(field_key)}={get_field_value(field_key)}")
        assn_str = f",\n{' '*16}".join(assignments)

        method_template = f"""
    def {get_method_name(t)}(self, 
        config: List[Dict[str, Any]]) -> Dict[str, {t}]:
        print('Building {t} objects...')
        lookup = {{}}
        for c in config:
            guid = c['{t}Id']
            lookup[guid] = {t}(
                {assn_str})
        return lookup"""
        methods.append(method_template)
        
        lookup = get_lookup_name(get_field_name(t))
        call = f"{lookup} = self.{get_method_name(t)}(pm_entities['{entity_key}'])"
        lookup_calls.append(call)
    except Exception as e:
        methods.append(
            f"\n        # failed to gen {entity_key} lookup"
            f"        # {repr(e)}")
        lookup_calls.append(f'# failed to gen {entity_key} lookup call')
            
lookup_calls_str = f"\n{' '*8}".join(lookup_calls)
methods_str = f"\n{' '*4}".join(methods)
class_template = f"""def lookup(dic: Dict[str, Any], id: str) -> Any:
    return None if id is None else dic[id]
    
    
class FullPropertyModelLoader:
    
    def __init__(self):
        pm_entities: Dict[str, Any] = json.loads(get_pm_config())
        {lookup_calls_str}
        
        {methods_str}
"""
print(class_template)
# Out:
# def lookup(dic: Dict[str, Any], id: str) -> Any:
#     return None if id is None else dic[id]
#
#
# class FullPropertyModelLoader:
#
#     def __init__(self):
#         pm_entities: Dict[str, Any] = json.loads(get_pm_config())
#         self.lookup_property_group = self.get_property_group_lookup(pm_entities['PropertyGroups'])
#         self.lookup_property_group_alias = self.get_property_group_alias_lookup(pm_entities['PropertyGroupAliases'])
#         self.lookup_indicator_group = self.get_indicator_group_lookup(pm_entities['IndicatorGroups'])
#         self.lookup_indicator = self.get_indicator_lookup(pm_entities['Indicators'])
#         self.lookup_ratio_group = self.get_ratio_group_lookup(pm_entities['RatioGroups'])
#         self.lookup_ratio = self.get_ratio_lookup(pm_entities['Ratios'])
#         self.lookup_unit_of_measure_group = self.get_unit_of_measure_group_lookup(pm_entities['UnitOfMeasureGroups'])
#         self.lookup_unit_of_measure = self.get_unit_of_measure_lookup(pm_entities['UnitsOfMeasure'])
#         self.lookup_unit_of_measure_alias = self.get_unit_of_measure_alias_lookup(pm_entities['UnitOfMeasureAliases'])
#         self.lookup_codelist = self.get_codelist_lookup(pm_entities['Codelists'])
#         self.lookup_codelist_entry = self.get_codelist_entry_lookup(pm_entities['CodelistEntries'])
#         self.lookup_codelist_entry_alias = self.get_codelist_entry_alias_lookup(pm_entities['CodelistEntryAliases'])
#         # failed to gen DataTypes lookup call
#         self.lookup_property = self.get_property_lookup(pm_entities['Properties'])
#         self.lookup_property_group_property = self.get_property_group_property_lookup(pm_entities['PropertyGroupProperties'])
#         self.lookup_property_group_property_alias = self.get_property_group_property_alias_lookup(pm_entities['PropertyGroupPropertyAliases'])
#         self.lookup_measurement_context = self.get_measurement_context_lookup(pm_entities['MeasurementContexts'])
#         self.lookup_equation = self.get_equation_lookup(pm_entities['Equations'])
#
#
#     def get_property_group_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, PropertyGroup]:
#         print('Building PropertyGroup objects...')
#         lookup = {}
#         for c in config:
#             guid = c['PropertyGroupId']
#             lookup[guid] = PropertyGroup(
#                 id=c['PropertyGroupId'],
#                 short_name=c['ShortName'],
#                 long_name=c['LongName'],
#                 igi_code=c['IgiCode'],
#                 is_analysis=c['IsAnalysis'],
#                 list_position=c['ListPosition'])
#         return lookup
#
#     def get_property_group_alias_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, PropertyGroupAlias]:
#         print('Building PropertyGroupAlias objects...')
#         lookup = {}
#         for c in config:
#             guid = c['PropertyGroupAliasId']
#             lookup[guid] = PropertyGroupAlias(
#                 id=c['PropertyGroupAliasId'],
#                 property_group=lookup(self.lookup_property_group, id=c['PropertyGroupId']),
#                 alias=c['Alias'])
#         return lookup
#
#     def get_indicator_group_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, IndicatorGroup]:
#         print('Building IndicatorGroup objects...')
#         lookup = {}
#         for c in config:
#             guid = c['IndicatorGroupId']
#             lookup[guid] = IndicatorGroup(
#                 id=c['IndicatorGroupId'],
#                 name=c['Name'])
#         return lookup
#
#     def get_indicator_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, Indicator]:
#         print('Building Indicator objects...')
#         lookup = {}
#         for c in config:
#             guid = c['IndicatorId']
#             lookup[guid] = Indicator(
#                 id=c['IndicatorId'],
#                 indicator_group=lookup(self.lookup_indicator_group, id=c['IndicatorGroupId']),
#                 long_name=c['LongName'],
#                 short_name=c['ShortName'],
#                 igi_code=c['IgiCode'],
#                 is_default=c['IsDefault'],
#                 is_null_equivalent=c['IsNullEquivalent'],
#                 position_in_indicator_group=c['PositionInIndicatorGroup'])
#         return lookup
#
#     def get_ratio_group_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, RatioGroup]:
#         print('Building RatioGroup objects...')
#         lookup = {}
#         for c in config:
#             guid = c['RatioGroupId']
#             lookup[guid] = RatioGroup(
#                 id=c['RatioGroupId'],
#                 name=c['Name'])
#         return lookup
#
#     def get_ratio_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, Ratio]:
#         print('Building Ratio objects...')
#         lookup = {}
#         for c in config:
#             guid = c['RatioId']
#             lookup[guid] = Ratio(
#                 id=c['RatioId'],
#                 ratio_group=lookup(self.lookup_ratio_group, id=c['RatioGroupId']),
#                 long_name=c['LongName'],
#                 symbol=c['Symbol'],
#                 igi_code=c['IgiCode'],
#                 is_base=c['IsBase'],
#                 is_null_equivalent=c['IsNullEquivalent'],
#                 position_in_ratio_group=c['PositionInRatioGroup'],
#                 conversion_parameters=c['ConversionParameters'])
#         return lookup
#
#     def get_unit_of_measure_group_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, UnitOfMeasureGroup]:
#         print('Building UnitOfMeasureGroup objects...')
#         lookup = {}
#         for c in config:
#             guid = c['UnitOfMeasureGroupId']
#             lookup[guid] = UnitOfMeasureGroup(
#                 id=c['UnitOfMeasureGroupId'],
#                 name=c['Name'])
#         return lookup
#
#     def get_unit_of_measure_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, UnitOfMeasure]:
#         print('Building UnitOfMeasure objects...')
#         lookup = {}
#         for c in config:
#             guid = c['UnitOfMeasureId']
#             lookup[guid] = UnitOfMeasure(
#                 id=c['UnitOfMeasureId'],
#                 unit_of_measure_group=lookup(self.lookup_unit_of_measure_group, id=c['UnitOfMeasureGroupId']),
#                 long_name=c['LongName'],
#                 symbol=c['Symbol'],
#                 is_base=c['IsBase'],
#                 is_null_equivalent=c['IsNullEquivalent'],
#                 conversion_parameters=c['ConversionParameters'],
#                 position_in_unit_of_measure_group=c['PositionInUnitOfMeasureGroup'])
#         return lookup
#
#     def get_unit_of_measure_alias_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, UnitOfMeasureAlias]:
#         print('Building UnitOfMeasureAlias objects...')
#         lookup = {}
#         for c in config:
#             guid = c['UnitOfMeasureAliasId']
#             lookup[guid] = UnitOfMeasureAlias(
#                 id=c['UnitOfMeasureAliasId'],
#                 unit_of_measure=lookup(self.lookup_unit_of_measure, id=c['UnitOfMeasureId']),
#                 alias=c['Alias'])
#         return lookup
#
#     def get_codelist_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, Codelist]:
#         print('Building Codelist objects...')
#         lookup = {}
#         for c in config:
#             guid = c['CodelistId']
#             lookup[guid] = Codelist(
#                 id=c['CodelistId'],
#                 name=c['Name'])
#         return lookup
#
#     def get_codelist_entry_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, CodelistEntry]:
#         print('Building CodelistEntry objects...')
#         lookup = {}
#         for c in config:
#             guid = c['CodelistEntryId']
#             lookup[guid] = CodelistEntry(
#                 id=c['CodelistEntryId'],
#                 codelist=lookup(self.lookup_codelist, id=c['CodelistId']),
#                 short_name=c['ShortName'],
#                 long_name=c['LongName'])
#         return lookup
#
#     def get_codelist_entry_alias_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, CodelistEntryAlias]:
#         print('Building CodelistEntryAlias objects...')
#         lookup = {}
#         for c in config:
#             guid = c['CodelistEntryAliasId']
#             lookup[guid] = CodelistEntryAlias(
#                 id=c['CodelistEntryAliasId'],
#                 codelist_entry=lookup(self.lookup_codelist_entry, id=c['CodelistEntryId']),
#                 alias=c['Alias'])
#         return lookup
#
#         # failed to gen DataTypes lookup        # KeyError('DataTypes')
#
#     def get_property_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, Property]:
#         print('Building Property objects...')
#         lookup = {}
#         for c in config:
#             guid = c['PropertyId']
#             lookup[guid] = Property(
#                 id=c['PropertyId'],
#                 short_name=c['ShortName'],
#                 long_name=c['LongName'],
#                 igi_code=c['IgiCode'],
#                 codelist=lookup(self.lookup_codelist, id=c['CodelistId']),
#                 data_type=lookup(self.lookup_data_type, id=c['DataTypeId']),
#                 default_ratio=lookup(self.lookup_ratio, id=c['DefaultRatioId']),
#                 physical_characteristics=c['PhysicalCharacteristics'])
#         return lookup
#
#     def get_property_group_property_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, PropertyGroupProperty]:
#         print('Building PropertyGroupProperty objects...')
#         lookup = {}
#         for c in config:
#             guid = c['PropertyGroupPropertyId']
#             lookup[guid] = PropertyGroupProperty(
#                 id=c['PropertyGroupPropertyId'],
#                 property_group=lookup(self.lookup_property_group, id=c['PropertyGroupId']),
#                 property=lookup(self.lookup_property, id=c['PropertyId']),
#                 position_in_property_group=c['PositionInPropertyGroup'],
#                 ion_channel=c['IonChannel'],
#                 description=c['Description'])
#         return lookup
#
#     def get_property_group_property_alias_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, PropertyGroupPropertyAlias]:
#         print('Building PropertyGroupPropertyAlias objects...')
#         lookup = {}
#         for c in config:
#             guid = c['PropertyGroupPropertyAliasId']
#             lookup[guid] = PropertyGroupPropertyAlias(
#                 id=c['PropertyGroupPropertyAliasId'],
#                 property_group_property=lookup(self.lookup_property_group_property, id=c['PropertyGroupPropertyId']),
#                 alias=c['Alias'])
#         return lookup
#
#     def get_measurement_context_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, MeasurementContext]:
#         print('Building MeasurementContext objects...')
#         lookup = {}
#         for c in config:
#             guid = c['MeasurementContextId']
#             lookup[guid] = MeasurementContext(
#                 id=c['MeasurementContextId'],
#                 property_group_property=lookup(self.lookup_property_group_property, id=c['PropertyGroupPropertyId']),
#                 indicator=lookup(self.lookup_indicator, id=c['IndicatorId']),
#                 default_ratio=lookup(self.lookup_ratio, id=c['DefaultValueDescriptorRatioId']),
#                 default_unit_of_measure=lookup(self.lookup_unit_of_measure, id=c['DefaultValueDescriptorUnitOfMeasureId']),
#                 default_value=c['DefaultValue'],
#                 decimal_places=c['DecimalPlaces'],
#                 absolute_min=c['AbsoluteMin'],
#                 absolute_max=c['AbsoluteMax'],
#                 typical_min=c['TypicalMin'],
#                 typical_max=c['TypicalMax'],
#                 typical_error=c['TypicalError'])
#         return lookup
#
#     def get_equation_lookup(self,
#         config: List[Dict[str, Any]]) -> Dict[str, Equation]:
#         print('Building Equation objects...')
#         lookup = {}
#         for c in config:
#             guid = c['EquationId']
#             lookup[guid] = Equation(
#                 id=c['EquationId'],
#                 measurement_context=lookup(self.lookup_measurement_context, id=c['MeasurementContextId']),
#                 value_descriptor=lookup(self.lookup_value_descriptor, id=c['ValueDescriptorId']),
#                 equation_expression=c['EquationExpression'])
#         return lookup
