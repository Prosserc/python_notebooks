# %%
import pandas as pd

# %%
fp = 'nns_vr_tmax_toc.csv'
with open(fp, encoding='utf-8') as f:
    df = pd.read_csv(f, skipinitialspace=True, encoding='utf-8')
df
# Out:
#       Base MD.Sample(m)  Lat.Any(°)  Long.Any(°) Type.Sample        Lith.Phys  \
# 0           4059.935994   56.396339     3.315175    Cuttings        Claystone
# 1           4320.000000   56.146997     3.454261   pCuttings             Coal
# 2           3105.000000   56.234464     3.707639   pCuttings  Shale/Claystone
# 3           3105.000000   56.234464     3.707639   pCuttings        Claystone
# 4           4170.000000   56.146997     3.454261   pCuttings  Shale/Claystone
# ...                 ...         ...          ...         ...              ...
# 1795        4522.000000   59.316653     2.211850    Cuttings        Claystone
# 1796        4552.000000   59.316653     2.211850    Cuttings        Claystone
# 1797        4627.000000   59.316653     2.211850    Cuttings        Claystone
# 1798        4681.000000   59.316653     2.211850    Cuttings        Claystone
# 1799        4729.000000   59.316653     2.211850    Cuttings        Claystone
#
#       TOC.Any(%wt)  T-max.Any(°C)  HI.Any(ppt (mg/g) (a/b))  \
# 0             2.83            445                186.572438
# 1            21.15            446                218.061466
# 2             0.70            426                100.000000
# 3             0.20            408                 50.000000
# 4             2.96            445                 77.702703
# ...            ...            ...                       ...
# 1795          5.77            457                139.168111
# 1796          7.63            462                130.275229
# 1797          3.94            450                142.639594
# 1798          2.10            447                263.333333
# 1799          2.63            448                240.304183
#
#       S1.Any(ppt (mg/g))  S2.Any(ppt (mg/g))  VR Mean.Any(%)
# 0                   0.93                5.28            0.28
# 1                   3.66               46.12            0.83
# 2                   0.50                0.70            0.39
# 3                   0.20                0.10            0.38
# 4                   0.39                2.30            0.71
# ...                  ...                 ...             ...
# 1795                0.15                8.03            1.09
# 1796                0.28                9.94            1.15
# 1797                0.12                5.62            1.15
# 1798                0.12                5.53            1.23
# 1799                0.10                6.32            1.33
#
# [1800 rows x 11 columns]

# %%
def get_n_hidden_units(n_rows: int, n_features: int) -> int:
    return int(min(100, max(10, (n_features * n_rows)/5)))

hidden_layer_sizes = [get_n_hidden_units(*df.shape)]
print(f"Hidden layer sizes: {hidden_layer_sizes}")
# Out:
# Hidden layer sizes: [100]

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.pipeline import Pipeline
import numpy as np

features = df.columns.values[:-1]
# excl text features for now
features = features.tolist()[:3] + features.tolist()[5:] 
targets = df.columns.values[-1]
seed = 42

X, y = df[features], df[targets]
X_trn, X_test, y_trn, y_test = train_test_split(X, y, train_size=0.7, random_state=seed)

regressor = MLPRegressor(hidden_layer_sizes=hidden_layer_sizes, random_state=seed)

def build_and_eval_pipeline(regressor):
    pipeline = Pipeline(steps=[
        ('Scale', StandardScaler()),
        ('Impute', KNNImputer()),
        ('Regression', regressor)])

    pipeline.fit(X_trn, y_trn)
    y_pred = pipeline.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    print(f"R²: {r2:.3f}, RMSE: {rmse:.2f}")
    
build_and_eval_pipeline(regressor)
# Out:
# R²: 0.579, RMSE: 0.17

# %%
# try with grid search
from sklearn.model_selection import GridSearchCV, KFold

param_grid = {
    "hidden_layer_sizes": [
        (100), (150), (200),
        (50, 50), (60, 40), (40, 60), 
        (33, 33, 33), (25, 50, 25),
        (25, 25, 25, 25),
        (20, 20, 20, 20, 20)],  
    "solver": ["lbfgs", "adam"]}

from warnings import simplefilter
from sklearn.exceptions import ConvergenceWarning
simplefilter("ignore", category=ConvergenceWarning)

kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
regressorSearch = GridSearchCV(regressor, param_grid, cv=kfold, verbose=2)
build_and_eval_pipeline(regressorSearch)

regressorSearch.best_params_
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ...............hidden_layer_sizes=100, solver=lbfgs; total time=   0.5s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=100, solver=adam; total time=   0.3s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.8s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.7s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.8s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.8s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.7s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.8s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.8s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.8s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.7s
# [CV] END ...............hidden_layer_sizes=150, solver=lbfgs; total time=   0.7s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.4s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.2s
# [CV] END ................hidden_layer_sizes=150, solver=adam; total time=   0.2s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   1.0s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ...............hidden_layer_sizes=200, solver=lbfgs; total time=   0.9s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.6s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.4s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.4s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.5s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.4s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.5s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.3s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.4s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.5s
# [CV] END ................hidden_layer_sizes=200, solver=adam; total time=   0.6s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.8s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(50, 50), solver=lbfgs; total time=   0.7s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.6s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(50, 50), solver=adam; total time=   0.6s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(60, 40), solver=lbfgs; total time=   0.7s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.6s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(60, 40), solver=adam; total time=   0.4s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.8s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.7s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.8s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.8s
# [CV] END ..........hidden_layer_sizes=(40, 60), solver=lbfgs; total time=   0.8s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.6s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.4s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.6s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.5s
# [CV] END ...........hidden_layer_sizes=(40, 60), solver=adam; total time=   0.4s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END ......hidden_layer_sizes=(33, 33, 33), solver=lbfgs; total time=   0.9s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(33, 33, 33), solver=adam; total time=   0.1s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END ......hidden_layer_sizes=(25, 50, 25), solver=lbfgs; total time=   0.8s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.2s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.2s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.2s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.1s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.2s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.2s
# [CV] END .......hidden_layer_sizes=(25, 50, 25), solver=adam; total time=   0.2s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ..hidden_layer_sizes=(25, 25, 25, 25), solver=lbfgs; total time=   1.0s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.1s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.1s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.1s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END ...hidden_layer_sizes=(25, 25, 25, 25), solver=adam; total time=   0.2s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.0s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.0s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   1.1s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=lbfgs; total time=   0.8s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.2s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.4s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.2s
# [CV] END hidden_layer_sizes=(20, 20, 20, 20, 20), solver=adam; total time=   0.3s
# R²: 0.661, RMSE: 0.15
# {'hidden_layer_sizes': (25, 50, 25), 'solver': 'adam'}

# %%
pd.DataFrame(regressorSearch.cv_results_).sort_values("rank_test_score")[:10]  # top 10
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15       0.247675      0.024059         0.000300        0.000458
# 11       0.586559      0.070133         0.000600        0.000490
# 3        0.383735      0.061579         0.000800        0.000400
# 5        0.549758      0.088224         0.000700        0.000458
# 17       0.273793      0.032703         0.000503        0.000503
# 9        0.537717      0.059958         0.000901        0.000300
# 7        0.600760      0.044620         0.000897        0.000299
# 13       0.186797      0.022567         0.000300        0.000458
# 19       0.382700      0.050610         0.000600        0.000490
# 1        0.338899      0.024631         0.000700        0.000458
#
#    param_hidden_layer_sizes param_solver  \
# 15             (25, 50, 25)         adam
# 11                 (40, 60)         adam
# 3                       150         adam
# 5                       200         adam
# 17         (25, 25, 25, 25)         adam
# 9                  (60, 40)         adam
# 7                  (50, 50)         adam
# 13             (33, 33, 33)         adam
# 19     (20, 20, 20, 20, 20)         adam
# 1                       100         adam
#
#                                                params  split0_test_score  \
# 15  {'hidden_layer_sizes': (25, 50, 25), 'solver':...           0.729470
# 11  {'hidden_layer_sizes': (40, 60), 'solver': 'ad...           0.730774
# 3       {'hidden_layer_sizes': 150, 'solver': 'adam'}           0.748153
# 5       {'hidden_layer_sizes': 200, 'solver': 'adam'}           0.703845
# 17  {'hidden_layer_sizes': (25, 25, 25, 25), 'solv...           0.713410
# 9   {'hidden_layer_sizes': (60, 40), 'solver': 'ad...           0.709555
# 7   {'hidden_layer_sizes': (50, 50), 'solver': 'ad...           0.707310
# 13  {'hidden_layer_sizes': (33, 33, 33), 'solver':...           0.694905
# 19  {'hidden_layer_sizes': (20, 20, 20, 20, 20), '...           0.670297
# 1       {'hidden_layer_sizes': 100, 'solver': 'adam'}           0.666358
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 15           0.600421           0.477587           0.630348
# 11           0.576561           0.475160           0.629478
# 3            0.539177           0.478367           0.618707
# 5            0.573315           0.462783           0.648571
# 17           0.545721           0.468406           0.610872
# 9            0.543099           0.447527           0.615752
# 7            0.549467           0.437110           0.584262
# 13           0.537817           0.463642           0.590998
# 19           0.565596           0.388367           0.612417
# 1            0.518587           0.425992           0.572632
#
#     split4_test_score  split5_test_score  split6_test_score  \
# 15           0.676580           0.660431           0.715417
# 11           0.656643           0.686364           0.727150
# 3            0.653903           0.663037           0.712688
# 5            0.623847           0.615554           0.675833
# 17           0.646042           0.581047           0.728785
# 9            0.576486           0.657738           0.712458
# 7            0.635610           0.654207           0.693803
# 13           0.637230           0.652958           0.700870
# 19           0.580607           0.609389           0.728867
# 1            0.588353           0.681602           0.624957
#
#     split7_test_score  split8_test_score  split9_test_score  mean_test_score  \
# 15           0.682975           0.745444           0.674447         0.659312
# 11           0.682413           0.704693           0.654726         0.652396
# 3            0.665379           0.693545           0.676879         0.644984
# 5            0.662362           0.722593           0.703408         0.639211
# 17           0.628244           0.731408           0.668568         0.632250
# 9            0.647408           0.704672           0.683542         0.629824
# 7            0.647803           0.681773           0.660871         0.625222
# 13           0.599520           0.680926           0.675565         0.623443
# 19           0.620757           0.716343           0.672052         0.616469
# 1            0.558764           0.646469           0.669593         0.595331
#
#     std_test_score  rank_test_score
# 15        0.073422                1
# 11        0.073643                2
# 3         0.076858                3
# 5         0.073131                4
# 17        0.080421                5
# 9         0.081583                6
# 7         0.077570                7
# 13        0.072579                8
# 19        0.091970                9
# 1         0.076132               10

# %%
features
# Out:
# ['Base MD.Sample(m)',
#  'Lat.Any(°)',
#  'Long.Any(°)',
#  'TOC.Any(%wt)',
#  'T-max.Any(°C)',
#  'HI.Any(ppt (mg/g) (a/b))',
#  'S1.Any(ppt (mg/g))',
#  'S2.Any(ppt (mg/g))']
